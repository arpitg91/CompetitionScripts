# %%
import os,sys,string,re
import pandas as pd
import numpy as np
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
import matplotlib.pyplot as plt

to_space= '''&,()+'"/'''
trans=string.maketrans(to_space, ' '*len(to_space))
ps = PorterStemmer()

os.chdir('/data/arpit.goel/31_PricePrediction/03.Submissions')
pd.set_option('display.float_format', lambda x: '%.1f' % x)

df_raw_train=pd.read_csv('../input/train.tsv',delimiter='\t')
df_raw_test=pd.read_csv('../input/test.tsv',delimiter='\t')
df_raw_train['log_price']=np.clip(np.log(1+df_raw_train['price']),1,5)

ins=df_raw_train.sample(frac=0.8,random_state=200)
oos=df_raw_train.drop(ins.index)
oot=get_features(df_raw_test)

# %%
def clean_category(x):
    if len(x)==0:
        return ''
    x=re.sub(chr(195),'e',x)
    x=re.sub(chr(169),'',x)
    x=x.translate(trans)
    x=re.sub(' +',' ',x)
    x=x.lower()
    x=' '.join(list(set(map(ps.stem,x.split(' ')))))
    x=re.sub('(\\b[A-Za-z] \\b|\\b [A-Za-z]\\b)', '',x)
    return x

def get_group_vars(df,x,threshold):
    df_group=df.groupby(x)[['count','log_price']].sum().reset_index()
    df_group['new_grp']=np.where(df_group['count']>threshold,df_group.index,-999)
    df_group_map=df_group[x+['new_grp']]
    df_group=df_group.groupby('new_grp')[['count','log_price']].sum()
    df_group['freq']=df_group['count']/df_group['count'].sum()
    df_group['avg_log_price']=df_group['log_price']/df_group['count']
    df_group_map['%s_freq'%'_'.join(x)]=df_group_map['new_grp'].map(df_group['freq'])
    df_group_map['%s_avg_price'%'_'.join(x)]=df_group_map['new_grp'].map(df_group['avg_log_price'])
    df=pd.merge(df,df_group_map[x+['%s_freq'%'_'.join(x),'%s_avg_price'%'_'.join(x)]],on=x)
    return df
  
cat_price=ins.groupby('category_name')['log_price'].apply(lambda x: {'log_price':x.sum(),'count':x.size}).unstack().reset_index()
cat_price['category0']=cat_price['category_name'].map(lambda x: str(x).split('/')[0]).map(clean_category)
cat_price['category1']=cat_price['category_name'].map(lambda x: str(x).split('/')[1] if str(x).count('/')>=1 else 'na').map(clean_category)
cat_price['category2']=cat_price['category_name'].map(lambda x: str(x).split('/')[2] if str(x).count('/')>=2 else 'na').map(clean_category)    
cat_price=get_group_vars(cat_price,['category0'],500)
cat_price=get_group_vars(cat_price,['category1'],500)
cat_price=get_group_vars(cat_price,['category2'],500)
cat_price=get_group_vars(cat_price,['category0','category1'],500)
cat_price=get_group_vars(cat_price,['category1','category2'],500)
cat_price=get_group_vars(cat_price,['category0','category2'],500)
cat_price=get_group_vars(cat_price,['category0','category1','category2'],500)
cat_cols=['category%d'%x for x in range(3)]
cat_price['cat_1_max_avg_price']=cat_price[['%s_avg_price'%x for x in cat_cols]].apply(lambda x: np.max(x),axis=1)
cat_price['cat_1_min_avg_price']=cat_price[['%s_avg_price'%x for x in cat_cols]].apply(lambda x: np.min(x),axis=1)
cat_price['cat_1_med_avg_price']=cat_price[['%s_avg_price'%x for x in cat_cols]].apply(lambda x: np.median(x),axis=1)
cat_price['cat_2_max_avg_price']=cat_price[['%s_%s_avg_price'%(x,y) for x in cat_cols for y in cat_cols if x<y]].apply(lambda x: np.max(x),axis=1)
cat_price['cat_2_min_avg_price']=cat_price[['%s_%s_avg_price'%(x,y) for x in cat_cols for y in cat_cols if x<y]].apply(lambda x: np.min(x),axis=1)
cat_price['cat_2_med_avg_price']=cat_price[['%s_%s_avg_price'%(x,y) for x in cat_cols for y in cat_cols if x<y]].apply(lambda x: np.median(x),axis=1)
cat_price=cat_price[[x for x in cat_price.columns if 'category_name' in x or '_freq' in x or '_avg_price' in x]]

brand_price=ins.groupby('brand_name')['log_price'].apply(lambda x: {'log_price':x.sum(),'count':x.size}).unstack().reset_index()
brand_price=get_group_vars(brand_price,['brand_name'],500)
brand_price=brand_price[[x for x in brand_price.columns if 'brand_name' in x or '_freq' in x or '_avg_price' in x]]

# %%
def get_condition(x):
    x=str(x).lower()
    x=re.sub('[^0-9a-zA-Z]+',' ',x)
    x=' '.join(list(set(map(ps.stem,x.split(' ')))))
    if 'descript yet no' in x:
        return 'no_description'
    elif 'new' in x or 'never' in x or 'nwot' in x or 'nwt' in x or 'onc' in x or 'twice' in x:
        return 'new'
    elif 'use' in x or 'flaw no' in x:
        return 'used'
    elif 'ship free' in x:
        return 'free_shipping'
    elif 'condit' in x:
        return 'used_good_condition'
    else:
        return 'other'
    
all_descriptions=pd.concat([df_raw_train['item_description'],df_raw_test['item_description']]).value_counts()
all_descriptions=pd.DataFrame(all_descriptions[all_descriptions>=100])
all_descriptions['description']=all_descriptions.index
all_descriptions=all_descriptions['description'].map(get_condition)

# %%
def get_features(df):
    df['condition']=df['item_description'].map(all_descriptions).fillna('other')
    df=pd.concat([df,pd.get_dummies(df['condition'])],axis=1)
    df=pd.merge(df,cat_price,on='category_name',how='left')
    df=pd.merge(df,brand_price,on='brand_name',how='left')
    df['words_in_description']=df['item_description'].astype(np.str).map(lambda x: x.count(' '))
    df['chars_in_description']=df['item_description'].astype(np.str).map(lambda x: len(x))
    df['words_in_name']=df['name'].map(lambda x: x.count(' '))
    df['chars_in_name']=df['name'].map(lambda x: len(x))
    df['cost_in_description']=df['item_description'].astype(np.str).map(lambda x: 1 if '[rm]' in x else 0)
    return df

ins_w_features=get_features(ins)
oos_w_features=get_features(oos)
oot_w_features=get_features(oot)

# %%
features=['item_condition_id','shipping']+ins_w_features.columns.tolist()[10:]
means=ins_w_features[features].mean()
ins_w_features=ins_w_features.fillna(means)
oos_w_features=oos_w_features.fillna(means)
oot_w_features=oot_w_features.fillna(means)

# %%
from sklearn.linear_model import Lasso
pd.set_option('display.float_format', lambda x: '%.4f' % x)

performance=[]
for alpha in [0,0.001,0.003,0.01,0.03,0.1,0.3,1]:
    reg=Lasso(alpha=alpha)
    reg.fit(ins_w_features[features],ins_w_features['log_price'])
    performance.append([alpha,reg.score(ins_w_features[features],ins_w_features['log_price']), reg.score(oos_w_features[features],oos_w_features['log_price'])])
    
pd.DataFrame(performance,columns=['alpha','train','test'])
# Out:
# /data/arpit.goel/anaconda/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:7: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#    alpha  train   test
# 0 0.0000 0.2945 0.2952
# 1 0.0010 0.2901 0.2903
# 2 0.0030 0.2875 0.2876
# 3 0.0100 0.2768 0.2771
# 4 0.0300 0.2317 0.2317
# 5 0.1000 0.0022 0.0020
# 6 0.3000 0.0007 0.0006
# 7 1.0000 0.0007 0.0006

# %%
reg=Lasso(alpha=0.01)
reg.fit(ins_w_features[features],ins_w_features['log_price'])
print pd.Series(reg.coef_,index=features).sort_values()
# Out:
# shipping                                  -0.2624
# item_condition_id                         -0.0466
# brand_name_freq                           -0.0000
# cat_2_med_avg_price                        0.0000
# cat_2_min_avg_price                        0.0000
# cat_1_med_avg_price                        0.0000
# cat_1_min_avg_price                        0.0000
# cat_1_max_avg_price                        0.0000
# category0_category1_category2_avg_price    0.0000
# category0_category1_category2_freq        -0.0000
# category0_category2_avg_price              0.0000
# category0_category2_freq                  -0.0000
# category1_category2_freq                  -0.0000
# category0_category1_avg_price              0.0000
# category1_category2_avg_price              0.0000
# other                                      0.0000
# free_shipping                             -0.0000
# new                                       -0.0000
# no_description                            -0.0000
# category0_category1_freq                  -0.0000
# used                                      -0.0000
# used_good_condition                       -0.0000
# cost_in_description                        0.0000
# category0_avg_price                        0.0000
# category1_freq                             0.0000
# category2_freq                            -0.0000
# category0_freq                             0.0000
# chars_in_description                       0.0001
# words_in_description                       0.0005
# words_in_name                              0.0039
# chars_in_name                              0.0045
# category1_avg_price                        0.1742
# cat_2_max_avg_price                        0.1995
# category2_avg_price                        0.3854
# brand_name_avg_price                       0.6579
# dtype: float64

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'n_estimators':10,'max_depth':np.arange(3,10,2)}
rfr=RandomForestRegressor(min_samples_leaf=5000,n_jobs=1,oob_score=True)
reg = GridSearchCV(rfr, parameters, n_jobs=-1)
reg.fit(ins_w_features[features],ins_w_features['log_price'])
reg.grid_scores_

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

rf_features=['category1_category2_avg_price','brand_name_avg_price','shipping','cat_2_med_avg_price',\
             'item_condition_id','cat_2_max_avg_price','chars_in_description','cat_2_min_avg_price',\
             'cat_1_min_avg_price','category0_category1_category2_avg_price','brand_name_freq']

rfr=RandomForestRegressor(n_estimators=5,max_depth=10,min_samples_leaf=500,n_jobs=-1,oob_score=True)
rfr.fit(ins_w_features[rf_features],ins_w_features['log_price'])
print rfr.score(ins_w_features[rf_features],ins_w_features['log_price'])
print rfr.score(oos_w_features[rf_features],oos_w_features['log_price'])

pd.Series(rfr.feature_importances_,index=rf_features).sort_values(ascending=False).cumsum()
# Out:
# 0.401115985616
# 0.399958014223
# category1_category2_avg_price             0.2633
# brand_name_avg_price                      0.5143
# cat_2_max_avg_price                       0.6913
# shipping                                  0.7943
# cat_2_med_avg_price                       0.8763
# item_condition_id                         0.9211
# cat_2_min_avg_price                       0.9449
# chars_in_description                      0.9676
# cat_1_min_avg_price                       0.9839
# brand_name_freq                           0.9941
# category0_category1_category2_avg_price   1.0000
# dtype: float64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#count_descp = TfidfVectorizer(max_features = 50000,ngram_range = (1,3),stop_words = "english")
#X=count_descp.fit_transform(ins_w_features['item_description'].fillna('No description yet'))
from sklearn.linear_model import Lasso
model = Lasso(alpha=0.01)
print("Fitting Model")
model.fit(X, ins_w_features['log_price'])
# Out:
# Fitting Model
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-84-bc2bd4a92566> in <module>()
#       5 model = Lasso(alpha=0.01)
#       6 print("Fitting Model")
# ----> 7 model.fit(X, ins_w_features['log_price'])
#       8
#
# /data/arpit.goel/anaconda/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.pyc in fit(self, X, y, check_input)
#     725                           random_state=self.random_state,
#     726                           selection=self.selection,
# --> 727                           check_input=False)
#     728             coef_[k] = this_coef[:, 0]
#     729             dual_gaps_[k] = this_dual_gap[0]
#
# /data/arpit.goel/anaconda/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.pyc in enet_path(X, y, l1_ratio, eps, n_alphas, alphas, precompute, Xy, copy_X, coef_init, verbose, return_n_iter, positive, check_input, **params)
#     452                 coef_, l1_reg, l2_reg, X.data, X.indices,
#     453                 X.indptr, y, X_sparse_scaling,
# --> 454                 max_iter, tol, rng, random, positive)
#     455         elif multi_output:
#     456             model = cd_fast.enet_coordinate_descent_multi_task(
#
# KeyboardInterrupt:

# %%
count_descp.get_feature_names()
# Out:
# [u'00',
#  u'00 00',
#  u'00 advantage',
#  u'00 advantage kindness',
#  u'00 bundles',
#  u'00 bundles 45',
#  u'00 buy',
#  u'00 buy pair',
#  u'00 free',
#  u'00 free shipping',
#  u'00 pm',
#  u'00 pm pacific',
#  u'00 purchased',
#  u'00 purchased free',
#  u'00 remember',
#  u'00 remember purchasing',
#  u'00 shipping',
#  u'00 sizing',
#  u'00 sizing currently',
#  u'000',
#  u'001',
#  u'002',
#  u'003',
#  u'007',
#  u'00ct',
#  u'00pm',
#  u'01',
#  u'01 oz',
#  u'01 product',
#  u'01 product details',
#  u'01 product detials',
#  u'010',
#  u'02',
#  u'02 authentic',
#  u'02 authentic yeah',
#  u'02 choose',
#  u'02 choose color',
#  u'02 fl',
#  u'02 fl oz',
#  u'02 long',
#  u'02 long order',
#  u'02 oz',
#  u'03',
#  u'03 2020',
#  u'03 authentic',
#  u'03 authentic new',
#  u'03 authentic yeah',
#  u'03 authentic yes',
#  u'03 long',
#  u'03 long order',
#  u'03 oz',
#  u'03 oz 0g',
#  u'04',
#  u'04 better',
#  u'04 better price',
#  u'04 buy',
#  u'04 buy item',
#  u'04 long',
#  u'04 long order',
#  u'04 oz',
#  u'05',
#  u'05 fl',
#  u'05 fl oz',
#  u'05 long',
#  u'05 long order',
#  u'05 oz',
#  u'05oz',
#  u'06',
#  u'06 buy',
#  u'06 buy item',
#  u'06 oz',
#  u'07',
#  u'07 oz',
#  u'08',
#  u'08 oz',
#  u'09',
#  u'0g',
#  u'0mm',
#  u'0oz',
#  u'10',
#  u'10 00',
#  u'10 10',
#  u'10 10 condition',
#  u'10 100',
#  u'10 100 authentic',
#  u'10 10x13',
#  u'10 11',
#  u'10 11 12',
#  u'10 11 perfect',
#  u'10 12',
#  u'10 12 medium',
#  u'10 13',
#  u'10 13 size',
#  u'10 14',
#  u'10 14 based',
#  u'10 15',
#  u'10 15 minutes',
#  u'10 16',
#  u'10 17',
#  u'10 18',
#  u'10 18 waistband',
#  u'10 20',
#  u'10 22',
#  u'10 25',
#  u'10 3x4',
#  u'10 3x4 handmade',
#  u'10 50',
#  u'10 5x10',
#  u'10 6x9',
#  u'10 75',
#  u'10 atm',
#  u'10 atm upc',
#  u'10 available',
#  u'10 black',
#  u'10 box',
#  u'10 brand',
#  u'10 brand new',
#  u'10 bundle',
#  u'10 bundled',
#  u'10 bundles',
#  u'10 business',
#  u'10 business days',
#  u'10 buy',
#  u'10 cm',
#  u'10 color',
#  u'10 colors',
#  u'10 comes',
#  u'10 condition',
#  u'10 condition size',
#  u'10 condition worn',
#  u'10 coupon',
#  u'10 days',
#  u'10 days care',
#  u'10 different',
#  u'10 discount',
#  u'10 dollars',
#  u'10 excellent',
#  u'10 excellent condition',
#  u'10 fee',
#  u'10 feet',
#  u'10 films',
#  u'10 fit',
#  u'10 fits',
#  u'10 fl',
#  u'10 fl oz',
#  u'10 free',
#  u'10 free shipping',
#  u'10 ft',
#  u'10 ft long',
#  u'10 good',
#  u'10 good condition',
#  u'10 great',
#  u'10 great condition',
#  u'10 green',
#  u'10 high',
#  u'10 hours',
#  u'10 inch',
#  u'10 inches',
#  u'10 inches tall',
#  u'10 items',
#  u'10 items 15',
#  u'10 just',
#  u'10 lbs',
#  u'10 like',
#  u'10 like new',
#  u'10 long',
#  u'10 men',
#  u'10 meter',
#  u'10 meters',
#  u'10 minutes',
#  u'10 miracle',
#  u'10 ml',
#  u'10 mm',
#  u'10 new',
#  u'10 nwt',
#  u'10 oz',
#  u'10 pack',
#  u'10 packs',
#  u'10 page',
#  u'10 pair',
#  u'10 pairs',
#  u'10 pcs',
#  u'10 perfect',
#  u'10 piece',
#  u'10 pieces',
#  u'10 plus',
#  u'10 price',
#  u'10 price firm',
#  u'10 purchase',
#  u'10 read',
#  u'10 read profile',
#  u'10 regular',
#  u'10 rm',
#  u'10 rm 15',
#  u'10 rm 30',
#  u'10 rm free',
#  u'10 sales',
#  u'10 seller',
#  u'10 sellers',
#  u'10 selling',
#  u'10 selling fee',
#  u'10 sheets',
#  u'10 size',
#  u'10 small',
#  u'10 smoke',
#  u'10 spandex',
#  u'10 spandex new',
#  u'10 super',
#  u'10 tall',
#  u'10 times',
#  u'10 total',
#  u'10 used',
#  u'10 white',
#  u'10 wide',
#  u'10 women',
#  u'10 worn',
#  u'10 worn times',
#  u'10 x13',
#  u'10 years',
#  u'100',
#  u'100 acrylic',
#  u'100 activated',
#  u'100 activated charcoal',
#  u'100 authentic',
#  u'100 authentic 100',
#  u'100 authentic ask',
#  u'100 authentic bought',
#  u'100 authentic box',
#  u'100 authentic brand',
#  u'100 authentic bundle',
#  u'100 authentic check',
#  u'100 authentic color',
#  u'100 authentic comes',
#  u'100 authentic don',
#  u'100 authentic excellent',
#  u'100 authentic firm',
#  u'100 authentic free',
#  u'100 authentic great',
#  u'100 authentic guarantee',
#  u'100 authentic guaranteed',
#  u'100 authentic highly',
#  u'100 authentic item',
#  u'100 authentic limited',
#  u'100 authentic michael',
#  u'100 authentic money',
#  u'100 authentic new',
#  u'100 authentic nike',
#  u'100 authentic original',
#  u'100 authentic pandora',
#  u'100 authentic price',
#  u'100 authentic purchased',
#  u'100 authentic retail',
#  u'100 authentic retails',
#  u'100 authentic ship',
#  u'100 authentic size',
#  u'100 authentic used',
#  u'100 authentic worn',
#  u'100 brand',
#  u'100 brand new',
#  u'100 cashmere',
#  u'100 complete',
#  u'100 completely',
#  u'100 cotton',
#  u'100 cotton machine',
#  u'100 cotton size',
#  u'100 firm',
#  u'100 firm hold',
#  u'100 genuine',
#  u'100 guarantee',
#  u'100 guaranteed',
#  u'100 guaranteed authentic',
#  u'100 honest',
#  u'100 human',
#  u'100 human hair',
#  u'100 hypo',
#  u'100 hypo allergenic',
#  u'100 leather',
#  u'100 mink',
#  u'100 ml',
#  u'100 natural',
#  u'100 natural organic',
#  u'100 new',
#  u'100 new high',
#  u'100 nylon',
#  u'100 organic',
#  u'100 original',
#  u'100 pcs',
#  u'100 pcs rm',
#  u'100 percent',
#  u'100 percent authentic',
#  u'100 pieces',
#  u'100 polyester',
#  u'100 polyester lining',
#  u'100 polyester machine',
#  u'100 polyester size',
#  u'100 positive',
#  u'100 purchased',
#  u'100 purchased item',
#  u'100 pure',
#  u'100 rayon',
#  u'100 real',
#  u'100 real mink',
#  u'100 recyclable',
#  u'100 recyclable 5mil',
#  u'100 recyclable padded',
#  u'100 rm',
#  u'100 rm 110',
#  u'100 rm 200',
#  u'100 satisfaction',
#  u'100 satisfaction guarantee',
#  u'100 satisfaction guaranteed',
#  u'100 satisfied',
#  u'100 silk',
#  u'100 soft',
#  u'100 sure',
#  u'100 sure want',
#  u'100 tested',
#  u'100 tested shipped',
#  u'100 uv',
#  u'100 uv protection',
#  u'100 vegan',
#  u'100 virgin',
#  u'100 viscose',
#  u'100 waterproof',
#  u'100 wool',
#  u'100 working',
#  u'1000',
#  u'1000 authentic',
#  u'100cm',
#  u'100g',
#  u'100ml',
#  u'101',
#  u'101 dalmatians',
#  u'101 money',
#  u'102',
#  u'103',
#  u'104',
#  u'105',
#  u'106',
#  u'107',
#  u'108',
#  u'1080p',
#  u'109',
#  u'10c',
#  u'10cm',
#  u'10days',
#  u'10days homepage',
#  u'10days homepage details',
#  u'10ft',
#  u'10ft cable',
#  u'10ft cable send',
#  u'10g',
#  u'10in',
#  u'10k',
#  u'10k 14k',
#  u'10k 14k 18k',
#  u'10k gold',
#  u'10k white',
#  u'10k white gold',
#  u'10k yellow',
#  u'10k yellow gold',
#  u'10kt',
#  u'10m',
#  u'10ml',
#  u'10mm',
#  u'10oz',
#  u'10oz 12oz',
#  u'10oz 12oz 18oz',
#  u'10pcs',
#  u'10seagirl',
#  u'10seagirl lot',
#  u'10th',
#  u'10w',
#  u'10x',
#  u'10x13',
#  u'10x13 12x15',
#  u'10x13 12x15 14x17',
#  u'10x13 aloha',
#  u'10x13 aloha balloons',
#  u'10x13 blue',
#  u'10x13 clear',
#  u'10x13 inches',
#  u'10x13 inches self',
#  u'10x13 mailers',
#  u'10x13 mailers available',
#  u'10x13 pink',
#  u'10x13 poly',
#  u'10x13 poly mailer',
#  u'10x13 poly mailers',
#  u'10x13 polymailers',
#  u'10x13 polymailers 15',
#  u'10x13 self',
#  u'10x13 white',
#  u'10x13 white blue',
#  u'11',
#  u'11 10',
#  u'11 11',
#  u'11 12',
#  u'11 12 13',
#  u'11 13',
#  u'11 14',
#  u'11 14 extender',
#  u'11 15',
#  u'11 16',
#  u'11 17',
#  u'11 20',
#  u'11 21',
#  u'11 25',
#  u'11 75',
#  u'11 black',
#  u'11 brand',
#  u'11 brand new',
#  u'11 brown',
#  u'11 color',
#  u'11 colors',
#  u'11 colors available',
#  u'11 fl',
#  u'11 fl oz',
#  u'11 good',
#  u'11 good condition',
#  u'11 great',
#  u'11 height',
#  u'11 inch',
#  u'11 inches',
#  u'11 long',
#  u'11 men',
#  u'11 new',
#  u'11 oz',
#  u'11 perfect',
#  u'11 perfect nap',
#  u'11 rm',
#  u'11 size',
#  u'11 tall',
#  u'11 wide',
#  u'11 women',
#  u'11 worn',
#  u'110',
#  u'110 rm',
#  u'110 rm available',
#  u'1100',
#  u'1100 mah',
#  u'110v',
#  u'112',
#  u'114',
#  u'115',
#  u'118',
#  u'11am',
#  u'11c',
#  u'11mm',
#  u'11s',
#  u'12',
#  u'12 00',
#  u'12 10',
#  u'12 11',
#  u'12 12',
#  u'12 13',
#  u'12 14',
#  u'12 15',
#  u'12 16',
#  u'12 17',
#  u'12 18',
#  u'12 18 month',
#  u'12 18 months',
#  u'12 18m',
#  u'12 20',
#  u'12 2019',
#  u'12 2019 water',
#  u'12 22',
#  u'12 24',
#  u'12 24 months',
#  u'12 25',
#  u'12 31',
#  u'12 5oz',
#  u'12 black',
#  u'12 brand',
#  u'12 brand new',
#  u'12 card',
#  u'12 card slots',
#  u'12 cm',
#  u'12 color',
#  u'12 colors',
#  u'12 different',
#  u'12 excellent',
#  u'12 fits',
#  u'12 fl',
#  u'12 fl oz',
#  u'12 free',
#  u'12 free shipping',
#  u'12 girls',
#  u'12 good',
#  u'12 good condition',
#  u'12 great',
#  u'12 great condition',
#  u'12 hour',
#  u'12 hours',
#  u'12 inch',
#  u'12 inches',
#  u'12 inches long',
#  u'12 inches tall',
#  u'12 kids',
#  u'12 length',
#  u'12 long',
#  u'12 medium',
#  u'12 medium large',
#  u'12 men',
#  u'12 mo',
#  u'12 month',
#  u'12 months',
#  u'12 mos',
#  u'12 new',
#  u'12 oz',
#  u'12 pack',
#  u'12 pairs',
#  u'12 pcs',
#  u'12 piece',
#  u'12 pieces',
#  u'12 regular',
#  u'12 rm',
#  u'12 size',
#  u'12 spandex',
#  u'12 super',
#  u'12 tall',
#  u'12 total',
#  u'12 wide',
#  u'12 women',
#  u'12 worn',
#  u'12 x6',
#  u'12 x6 roll',
#  u'120',
#  u'1200',
#  u'120gb',
#  u'120gb 160gb',
#  u'120gb 160gb ipod',
#  u'125',
#  u'125 ml',
#  u'127',
#  u'128',
#  u'128 gb',
#  u'128gb',
#  u'129',
#  u'12c',
#  u'12g',
#  u'12in',
#  u'12m',
#  u'12mm',
#  u'12months',
#  u'12oz',
#  u'12oz 18oz',
#  u'12oz 18oz 20oz',
#  u'12pcs',
#  u'12pm',
#  u'12s',
#  u'12v',
#  u'12x12',
#  u'12x15',
#  u'12x15 14x17',
#  u'12x15 14x17 bubble',
#  u'12x15 hot',
#  u'12x15 hot pink',
#  u'12x15 inches',
#  u'12x15 inches self',
#  u'13',
#  u'13 10',
#  u'13 13',
#  u'13 14',
#  u'13 15',
#  u'13 16',
#  u'13 5cm',
#  u'13 5oz',
#  u'13 cm',
#  u'13 fl',
#  u'13 fl oz',
#  u'13 inch',
#  u'13 inches',
#  u'13 inches long',
#  u'13 length',
#  u'13 men',
#  u'13 oz',
#  u'13 size',
#  u'13 tall',
#  u'13 waist',
#  u'13 wide',
#  u'130',
#  u'135',
#  u'13c',
#  u'13cm',
#  u'13mm',
#  u'13oz',
#  u'14',
#  u'14 00',
#  u'14 10',
#  u'14 11',
#  u'14 12',
#  u'14 15',
#  u'14 16',
#  u'14 17',
#  u'14 18',
#  u'14 20',
#  u'14 5mm',
#  u'14 5mm monthly',
#  u'14 based',
#  u'14 based fit',
#  u'14 days',
#  u'14 diameter',
#  u'14 extender',
#  u'14 fl',
#  u'14 fl oz',
#  u'14 gauge',
#  u'14 gauge surgical',
#  u'14 inch',
#  u'14 inches',
#  u'14 karat',
#  u'14 length',
#  u'14 long',
#  u'14 mm',
#  u'14 mm base',
#  u'14 oz',
#  u'14 price',
#  u'14 shades',
#  u'14 waist',
#  u'14 wide',
#  u'140',
#  u'142',
#  u'142 concealer',
#  u'142 concealer buffer',
#  u'144',
#  u'145',
#  u'149',
#  u'14g',
#  u'14g surgical',
#  u'14g surgical steel',
#  u'14k',
#  u'14k 18k',
#  u'14k gold',
#  u'14k gold filled',
#  u'14k gold finish',
#  u'14k gold plated',
#  u'14k solid',
#  u'14k solid gold',
#  u'14k white',
#  u'14k white gold',
#  u'14k yellow',
#  u'14k yellow gold',
#  u'14kt',
#  u'14kt gold',
#  u'14mm',
#  u'14oz',
#  u'14x17',
#  u'14x17 bubble',
#  u'14x17 bubble mailers',
#  u'15',
#  u'15 00',
#  u'15 10',
#  u'15 10x13',
#  u'15 12',
#  u'15 15',
#  u'15 16',
#  u'15 17',
#  u'15 20',
#  u'15 20 minutes',
#  u'15 25',
#  u'15 6x9',
#  u'15 bundles',
#  u'15 color',
#  u'15 colors',
#  u'15 days',
#  u'15 discount',
#  u'15 fl',
#  u'15 free',
#  u'15 free shipping',
#  u'15 inch',
#  u'15 inches',
#  u'15 items',
#  u'15 items purchased',
#  u'15 laptop',
#  u'15 length',
#  u'15 long',
#  u'15 minutes',
#  u'15 ml',
#  u'15 oz',
#  u'15 pairs',
#  u'15 piece',
#  u'15 pieces',
#  u'15 rm',
#  u'15 rm 20',
#  u'15 rm blue',
#  u'15 rm thank',
#  u'15 spandex',
#  u'15 times',
#  u'15 total',
#  u'15 waist',
#  u'150',
#  u'1500',
#  u'15cm',
#  u'15g',
#  u'15ml',
#  u'15mm',
#  u'15oz',
#  u'15pcs',
#  u'15w',
#  u'16',
#  u'16 00',
#  u'16 12',
#  u'16 16',
#  u'16 17',
#  u'16 18',
#  u'16 20',
#  u'16 9oz',
#  u'16 bubble',
#  u'16 bubble wrap',
#  u'16 clips',
#  u'16 clips pcs',
#  u'16 count',
#  u'16 fl',
#  u'16 fl oz',
#  u'16 gauge',
#  u'16 gb',
#  u'16 hours',
#  u'16 inch',
#  u'16 inches',
#  u'16 inches enjoy',
#  u'16 inches long',
#  u'16 length',
#  u'16 long',
#  u'16 oz',
#  u'16 rm',
#  u'16 waist',
#  u'160',
#  u'160g',
#  u'160g 16',
#  u'160g 16 clips',
#  u'160gb',
#  u'160gb ipod',
#  u'160gb ipod nano',
#  u'165',
#  u'168',
#  u'16cm',
#  u'16ct',
#  u'16g',
#  u'16gb',
#  u'16gb 32gb',
#  u'16gb 32gb 64gb',
#  u'16gb rm',
#  u'16gb rm iphone',
#  u'16l',
#  u'16mm',
#  u'16oz',
#  u'17',
#  u'17 17',
#  u'17 18',
#  u'17 fl',
#  u'17 fl oz',
#  u'17 inches',
#  u'17 length',
#  u'17 oz',
#  u'17 waist',
#  u'170',
#  u'175',
#  u'17oz',
#  u'18',
#  u'18 00',
#  u'18 12',
#  u'18 18',
#  u'18 19',
#  u'18 20',
#  u'18 24',
#  u'18 24 month',
#  u'18 24 months',
#  u'18 24m',
#  u'18 55mm',
#  u'18 black',
#  u'18 chain',
#  u'18 colors',
#  u'18 doll',
#  u'18 double',
#  u'18 double wall',
#  u'18 hours',
#  u'18 inch',
#  u'18 inch doll',
#  u'18 inches',
#  u'18 inches long',
#  u'18 length',
#  u'18 long',
#  u'18 mo',
#  u'18 month',
#  u'18 months',
#  u'18 mos',
#  u'18 oz',
#  u'18 stainless',
#  u'18 stainless steel',
#  u'18 waistband',
#  u'18 waistband elastic',
#  u'180',
#  u'1800',
#  u'1800 1900',
#  u'1800 series',
#  u'1800 series piece',
#  u'18650',
#  u'18650 battery',
#  u'18g',
#  u'18in',
#  u'18k',
#  u'18k gold',
#  u'18k gold plated',
#  u'18k white',
#  u'18k white gold',
#  u'18m',
#  u'18mm',
#  u'18months',
#  u'18oz',
#  u'18oz 20oz',
#  u'18oz 20oz 36oz',
#  u'18th',
#  u'18w',
#  u'19',
#  u'19 21',
#  u'19 99',
#  u'19 inches',
#  u'19 length',
#  u'190',
#  u'1900',
#  u'1960',
#  u'1969',
#  u'1970',
#  u'1980',
#  u'1983',
#  u'1984',
#  u'1985',
#  u'1986',
#  u'1987',
#  u'1988',
#  u'1989',
#  u'199',
#  u'1990',
#  u'1991',
#  u'1992',
#  u'1993',
#  u'1994',
#  u'1995',
#  u'1996',
#  u'1997',
#  u'1998',
#  u'1999',
#  u'19mm',
#  u'19th',
#  u'19th birthday',
#  u'1a',
#  u'1b',
#  u'1c',
#  u'1cm',
#  u'1fl',
#  u'1fl oz',
#  u'1g',
#  u'1gb',
#  u'1in',
#  u'1in kraft',
#  u'1in kraft thank',
#  u'1in white',
#  u'1in white thank',
#  u'1inch',
#  u'1inch size',
#  u'1inch size quarter',
#  u'1m',
#  u'1m 3ft',
#  u'1m 3ft iphone',
#  u'1ml',
#  u'1mm',
#  u'1oz',
#  u'1pc',
#  u'1pcs',
#  u'1pm',
#  u'1pm friday',
#  u'1pm friday shipped',
#  u'1s',
#  u'1st',
#  u'1st class',
#  u'1st come',
#  u'1st come 1st',
#  u'1st edition',
#  u'1st generation',
#  u'1st photo',
#  u'1st pic',
#  u'1st picture',
#  u'1st serve',
#  u'1tb',
#  u'1x',
#  u'1x 10',
#  u'1x 2x',
#  u'1x 2x 3x',
#  u'1x black',
#  u'1x dry',
#  u'1x pc',
#  u'1x pc case',
#  u'1x tempered',
#  u'1x tempered glass',
#  u'1x usb',
#  u'1x wet',
#  u'1x wet wipe',
#  u'1x2in',
#  u'1x2in pink',
#  u'1x2in pink fragile',
#  u'1xl',
#  u'1y',
#  u'20',
#  u'20 00',
#  u'20 10x13',
#  u'20 22',
#  u'20 24',
#  u'20 25',
#  u'20 30',
#  u'20 30 minutes',
#  u'20 discount',
#  u'20 gauge',
#  u'20 inch',
#  u'20 inches',
#  u'20 inches long',
#  u'20 items',
#  u'20 lbs',
#  u'20 length',
#  u'20 long',
#  u'20 minutes',
#  u'20 oz',
#  u'20 pairs',
#  u'20 pcs',
#  u'20 pcs rm',
#  u'20 pieces',
#  u'20 polyester',
#  u'20 rm',
#  u'20 rm 25',
#  u'20 rm 30',
#  u'20 rm pic',
#  u'20 rm ships',
#  u'20 spandex',
#  u'20 thank',
#  u'20 thank sticker',
#  u'20 years',
#  u'200',
#  u'200 rm',
#  u'2000',
#  u'2000 games',
#  u'2000 games systems',
#  u'2001',
#  u'2002',
#  u'2003',
#  u'2004',
#  u'2005',
#  u'2006',
#  u'2007',
#  u'2008',
#  u'2009',
#  u'200ml',
#  u'2010',
#  u'2011',
#  u'2012',
#  u'2013',
#  u'2014',
#  u'2015',
#  u'2016',
#  u'2016 17',
#  u'2016 2017',
#  u'2016 fashion',
#  u'2016 fashion jewelry',
#  u'2016 holiday',
#  u'2016 new',
#  u'2017',
#  u'2017 new',
#  u'2018',
#  u'2019',
#  u'2019 water',
#  u'2019 water content',
#  u'2020',
#  u'2021',
#  u'2021 korea',
#  u'2021 korea available',
#  u'207',
#  u'208',
#  u'209',
#  u'20cm',
#  u'20g',
#  u'20in',
#  u'20khz',
#  u'20ml',
#  u'20mm',
#  u'20oz',
#  u'20oz 36oz',
#  u'20oz 36oz 64oz',
#  u'20pcs',
#  u'20th',
#  u'20w',
#  u'21',
#  u'21 american',
#  u'21 american apparel',
#  u'21 american eagle',
#  u'21 asos',
#  u'21 black',
#  u'21 brand',
#  u'21 brandy',
#  u'21 brandy melville',
#  u'21 charlotte',
#  u'21 charlotte russe',
#  ...]

# %%
def clean_description(x):
    if len(x)==0:
        return ''
    x=x.lower()
    return x

from collections import Counter
char_count=Counter([y for x in ins_w_features['item_description'].astype(np.str) for y in x])

# %%
pd.Series(char_count).sort_values(ascending=False).shape
# Out:
# (197,)
