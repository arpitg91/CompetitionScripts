# %%
import cPickle as pickle

clf = pickle.load( open( '/home/arpit.goel2/arpit.goel/06_WTS_Model/wts_kmeans_model.pkl', 'rb' ) )
scaler = pickle.load( open( '/home/arpit.goel2/arpit.goel/06_WTS_Model/wts_preprocessor.pkl', 'rb' ) )
# Out:
# /data/arpit.goel/anaconda/anaconda2/lib/python2.7/site-packages/sklearn/base.py:315: UserWarning: Trying to unpickle estimator KMeans from version pre-0.18 when using version 0.18.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /data/arpit.goel/anaconda/anaconda2/lib/python2.7/site-packages/sklearn/base.py:315: UserWarning: Trying to unpickle estimator StandardScaler from version pre-0.18 when using version 0.18.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
import pandas as pd
select_headers_cl = ['TCM_Flag','BC_Flag','PHR_Flag','DYN_Flag','REDEEM_RATE_QEB','REDEEM_RATE_CEB',\
                     'REDEEM_RATE_PHR','REDEEM_RATE_BC','REDEEM_RATE_TCM','REDEEM_RATE_OAR','REDEEM_RATE_DYN']

dict1 = {2:"01. Personalized (EM)",4:"02.  All ways to save mass+pers (full store FS+Rx)",8:"03. Personalized (TCM)",0:"04. Mass savers",5:"05. Mass, PHR(RX)",7:"06. Mass, All Ebs",6:"07. Mass, Convenience(QEB)",9:"08. Mass, CEB lovers",1:"09. Convenience (Low Coupons)",3:"10. Extreme Non-EC Coupons"}


pd.DataFrame(clf.cluster_centers_,columns=select_headers_cl,index=[dict1[x] for x in range(10)])
# Out:
#                                                     TCM_Flag   BC_Flag  \
# 04. Mass savers                                     0.230388  0.954904
# 09. Convenience (Low Coupons)                      -0.180928 -0.158099
# 01. Personalized (EM)                               0.260903  0.541470
# 10. Extreme Non-EC Coupons                         -0.264153 -0.154262
# 02.  All ways to save mass+pers (full store FS+Rx)  0.314425  0.949257
# 05. Mass, PHR(RX)                                   0.185806 -0.117550
# 07. Mass, Convenience(QEB)                         -0.014789 -0.126390
# 06. Mass, All Ebs                                   0.188800 -0.064760
# 03. Personalized (TCM)                              0.521032  0.128226
# 08. Mass, CEB lovers                               -0.148277 -0.165635
#
#                                                     PHR_Flag  DYN_Flag  \
# 04. Mass savers                                    -0.093178  0.114283
# ...

# %%
pd.Series(scaler.std_,index=select_headers_cl)
# Out:
# /data/arpit.goel/anaconda/anaconda2/lib/python2.7/site-packages/sklearn/utils/deprecation.py:70: DeprecationWarning: Function std_ is deprecated; Attribute ``std_`` will be removed in 0.19. Use ``scale_`` instead
#   warnings.warn(msg, category=DeprecationWarning)
# TCM_Flag           0.499576
# BC_Flag            0.410944
# PHR_Flag           0.290845
# DYN_Flag           0.461957
# REDEEM_RATE_QEB    0.411205
# REDEEM_RATE_CEB    0.420680
# REDEEM_RATE_PHR    0.229173
# REDEEM_RATE_BC     0.314088
# REDEEM_RATE_TCM    0.143871
# REDEEM_RATE_OAR    0.051448
# REDEEM_RATE_DYN    0.081230
# dtype: float64
