# %%
import os
os.chdir('C:/Users/arpit.goel/Documents/Projects/Kaggle/15.RecruitRestarauntPrediction/00.Scripts')
# %run 04.FirstPlaceSolution.py
# Out:
# data key?:('2017-03-12', 39)
# add label
# make feature...
# 04.FirstPlaceSolution.py:298: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   'air_reserve_count': 'count'})
# 04.FirstPlaceSolution.py:300: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   {'air_store_diff_time_mean': 'mean'})
# 04.FirstPlaceSolution.py:302: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   {'air_diff_time_mean': 'mean'})
# 04.FirstPlaceSolution.py:306: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   'air_date_count': 'count'})
# 04.FirstPlaceSolution.py:310: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   'hpg_reserve_count': 'count'})
# ...

# %%
pd.Series(gbm.feature_importance(),index=predictors).sort_values(ascending=False).to_csv('feat_imp.csv')

# %%
import pickle
# store=pd.HDFStore('../01.RawData/FirstPlaceSol.h5')
# store['train_feat']=train_feat
# store['test_feat']=test_feat
# store.close()
output = open('../01.RawData/FirstPlaceSol.pkl', 'wb')
pickle.dump(gbm,output)
output.close()

# %%
len(predictors)
# Out:
# 217
